# %%
dbutils.fs.ls("/FileStore/shared_uploads/joshigaurav4301@gmail.com")
# Out:
# Out[145]: [FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/1800.csv', name='1800.csv', size=62728, modificationTime=1724346814000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/1800__1_.csv', name='1800__1_.csv', size=62728, modificationTime=1725390040000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/2015_summary.csv', name='2015_summary.csv', size=7080, modificationTime=1710588524000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Book', name='Book', size=264875, modificationTime=1724588097000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Book1.xlsx', name='Book1.xlsx', size=10224, modificationTime=1706427047000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Graph', name='Marvel_Graph', size=1673543, modificationTime=1726425937000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Graph-1', name='Marvel_Graph-1', size=1673543, modificationTime=1726508693000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Names', name='Marvel_Names', size=351848, modificationTime=1726427881000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Names-1', name='Marvel_Names-1', size=351848, modificationTime=1726428558000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Names-2', name='Marvel_Names-2', size=351848, modificationTime=1726429252000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/Marvel_Names-3', name='Marvel_Names-3', size=351848, modificationTime=1726508481000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/book.txt', name='book.txt', size=264875, modificationTime=1725383584000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/customer_orders.csv', name='customer_orders.csv', size=146855, modificationTime=1724693683000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/customer_orders__1_.csv', name='customer_orders__1_.csv', size=146855, modificationTime=1725470859000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/deliveries.csv', name='deliveries.csv', size=27019935, modificationTime=1730486171000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/f-1.data', name='f-1.data', size=1979173, modificationTime=1725555939000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/f-2.data', name='f-2.data', size=1979173, modificationTime=1726424715000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/f.data', name='f.data', size=1979173, modificationTime=1724084406000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/fakefriends-1.csv', name='fakefriends-1.csv', size=8754, modificationTime=1724950611000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/fakefriends.csv', name='fakefriends.csv', size=8754, modificationTime=1724172172000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/fakefriends_header.csv', name='fakefriends_header.csv', size=8779, modificationTime=1725299200000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/mssql_jdbc_12_6_1_jre8_sources-1.jar', name='mssql_jdbc_12_6_1_jre8_sources-1.jar', size=977268, modificationTime=1711479755000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/mssql_jdbc_12_6_1_jre8_sources-2.jar', name='mssql_jdbc_12_6_1_jre8_sources-2.jar', size=977268, modificationTime=1711561880000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/mssql_jdbc_12_6_1_jre8_sources.jar', name='mssql_jdbc_12_6_1_jre8_sources.jar', size=977268, modificationTime=1711479654000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/nameee-1.csv', name='nameee-1.csv', size=285, modificationTime=1710174468000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/nameee-2.csv', name='nameee-2.csv', size=285, modificationTime=1710174531000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/nameee.csv', name='nameee.csv', size=285, modificationTime=1710174409000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/new_3.txt', name='new_3.txt', size=33, modificationTime=1708831471000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/new_4.xml', name='new_4.xml', size=249, modificationTime=1711390697000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/people.json', name='people.json', size=43, modificationTime=1710572267000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/popular_movies_dataframe.py', name='popular_movies_dataframe.py', size=933, modificationTime=1725474558000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/postgresql_42_7_3.jar', name='postgresql_42_7_3.jar', size=1089312, modificationTime=1711876934000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u-1.data', name='u-1.data', size=1979173, modificationTime=1722932290000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u-1.item', name='u-1.item', size=236344, modificationTime=1726420707000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u-2.data', name='u-2.data', size=1979173, modificationTime=1724084354000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u-2.item', name='u-2.item', size=236344, modificationTime=1726421259000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u.data', name='u.data', size=1979173, modificationTime=1722932235000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/u.item', name='u.item', size=236344, modificationTime=1726420108000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/joshigaurav4301@gmail.com/userdata1.parquet', name='userdata1.parquet', size=113629, modificationTime=1710960070000)]

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fbb402a9-ada3-4cf2-8ed2-3253b4f477b9/lib/python3.9/site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fbb402a9-ada3-4cf2-8ed2-3253b4f477b9/lib/python3.9/site-packages (from pyspark) (0.10.9.7)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-fbb402a9-ada3-4cf2-8ed2-3253b4f477b9/bin/python -m pip install --upgrade pip' command.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.window import Window
import pyspark.sql.functions as f

# %%
spark=SparkSession.builder.appName("IPLScoreCard").getOrCreate()

# %%
df=spark.read.option("header",True).csv("/FileStore/shared_uploads/joshigaurav4301@gmail.com/deliveries.csv")

# %%
df.columns
# Out:
# Out[150]: ['match_id',
#  'inning',
#  'batting_team',
#  'bowling_team',
#  'over',
#  'ball',
#  'batter',
#  'bowler',
#  'non_striker',
#  'batsman_runs',
#  'extra_runs',
#  'total_runs',
#  'extras_type',
#  'is_wicket',
#  'player_dismissed',
#  'dismissal_kind',
#  'fielder']

# %%
Int_fields=['match_id','inning','over','ball','batsman_runs','extra_runs','total_runs','is_wicket']

# %%
Fields=[StructField(col,IntegerType(),True) if col in Int_fields else StructField(col,StringType(),True) for col in df.columns]
Fields
# Out:
# Out[152]: [StructField('match_id', IntegerType(), True),
#  StructField('inning', IntegerType(), True),
#  StructField('batting_team', StringType(), True),
#  StructField('bowling_team', StringType(), True),
#  StructField('over', IntegerType(), True),
#  StructField('ball', IntegerType(), True),
#  StructField('batter', StringType(), True),
#  StructField('bowler', StringType(), True),
#  StructField('non_striker', StringType(), True),
#  StructField('batsman_runs', IntegerType(), True),
#  StructField('extra_runs', IntegerType(), True),
#  StructField('total_runs', IntegerType(), True),
#  StructField('extras_type', StringType(), True),
#  StructField('is_wicket', IntegerType(), True),
#  StructField('player_dismissed', StringType(), True),
#  StructField('dismissal_kind', StringType(), True),
#  StructField('fielder', StringType(), True)]

# %%
df=spark.read.option("header","true").schema(StructType(Fields)).csv("/FileStore/shared_uploads/joshigaurav4301@gmail.com/deliveries.csv")

# %%
df.printSchema()
# Out:
# root
#  |-- match_id: integer (nullable = true)
#  |-- inning: integer (nullable = true)
#  |-- batting_team: string (nullable = true)
#  |-- bowling_team: string (nullable = true)
#  |-- over: integer (nullable = true)
#  |-- ball: integer (nullable = true)
#  |-- batter: string (nullable = true)
#  |-- bowler: string (nullable = true)
#  |-- non_striker: string (nullable = true)
#  |-- batsman_runs: integer (nullable = true)
#  |-- extra_runs: integer (nullable = true)
#  |-- total_runs: integer (nullable = true)
#  |-- extras_type: string (nullable = true)
#  |-- is_wicket: integer (nullable = true)
#  |-- player_dismissed: string (nullable = true)
#  |-- dismissal_kind: string (nullable = true)
#  |-- fielder: string (nullable = true)

# %%
newdf=df.select('match_id').distinct().orderBy(f.desc(f.col("match_id"))).cache()
new=newdf.first()

# %%
IPL_2024=df.filter(f.col("match_id")==new["match_id"])

# %%
FirstInnings=IPL_2024.filter("inning==1")

# %%
Manipulated_DF=FirstInnings.withColumn("over-ball",f.concat(f.lit(f.col("over")),f.lit("."),f.lit(f.col("ball"))).cast(FloatType
                                                                                                        ()))

# %%
Batting_Order=Manipulated_DF.groupBy("batter").agg(f.min(f.col("over-ball")).alias("order")).orderBy(f.col("order"))
Batting_Order=Batting_Order.withColumn("batting-order",f.row_number().over(Window.orderBy("order"))).select("batter","batting-order")
Batting_Order.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batter</th><th>batting-order</th></tr></thead><tbody><tr><td>Abhishek Sharma</td><td>1</td></tr><tr><td>RA Tripathi</td><td>2</td></tr><tr><td>TM Head</td><td>3</td></tr><tr><td>AK Markram</td><td>4</td></tr><tr><td>Nithish Kumar Reddy</td><td>5</td></tr><tr><td>H Klaasen</td><td>6</td></tr><tr><td>Shahbaz Ahmed</td><td>7</td></tr><tr><td>Abdul Samad</td><td>8</td></tr><tr><td>PJ Cummins</td><td>9</td></tr><tr><td>JD Unadkat</td><td>10</td></tr><tr><td>B Kumar</td><td>11</td></tr></tbody></table></div>

# %%
Scorecard=FirstInnings.filter( (f.col("extras_type").isNull()) | (f.col("extras_type")!="wides")).groupBy("batter").agg(f.sum("batsman_runs").alias("runs"),
                                   f.count("ball").alias("balls"),
                                   f.count(f.when(f.col("batsman_runs")==4,1)).alias("fours"),
                                   f.count(f.when(f.col("batsman_runs")==6,1)).alias("sixes"),
                                   f.round(f.sum("batsman_runs")/f.count("ball")*100,2).alias("strikeRate")

                                   )

# %%
Total_ScoreCard=Scorecard.join(Batting_Order,on="batter",how="inner").orderBy("batting-order").select("batter","runs","balls","fours","sixes","strikeRate")
Total_ScoreCard.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batter</th><th>runs</th><th>balls</th><th>fours</th><th>sixes</th><th>strikeRate</th></tr></thead><tbody><tr><td>Abhishek Sharma</td><td>2</td><td>5</td><td>0</td><td>0</td><td>40.0</td></tr><tr><td>RA Tripathi</td><td>9</td><td>13</td><td>1</td><td>0</td><td>69.23</td></tr><tr><td>TM Head</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0.0</td></tr><tr><td>AK Markram</td><td>20</td><td>23</td><td>3</td><td>0</td><td>86.96</td></tr><tr><td>Nithish Kumar Reddy</td><td>13</td><td>10</td><td>1</td><td>1</td><td>130.0</td></tr><tr><td>H Klaasen</td><td>16</td><td>17</td><td>1</td><td>0</td><td>94.12</td></tr><tr><td>Shahbaz Ahmed</td><td>8</td><td>7</td><td>0</td><td>1</td><td>114.29</td></tr><tr><td>Abdul Samad</td><td>4</td><td>4</td><td>0</td><td>0</td><td>100.0</td></tr><tr><td>PJ Cummins</td><td>24</td><td>19</td><td>2</td><td>1</td><td>126.32</td></tr><tr><td>JD Unadkat</td><td>4</td><td>11</td><td>0</td><td>0</td><td>36.36</td></tr><tr><td>B Kumar</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0.0</td></tr></tbody></table></div>

# %%
FirstInnings=FirstInnings.withColumn("Runwides",f.when(f.col("extras_type")=="wides",1).otherwise(0))
FirstInnings=FirstInnings.withColumn("RunsInOver",f.sum(f.col("batsman_runs")+f.col("Runwides")).over(Window.partitionBy("bowler","over")))
FirstInnings.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>match_id</th><th>inning</th><th>batting_team</th><th>bowling_team</th><th>over</th><th>ball</th><th>batter</th><th>bowler</th><th>non_striker</th><th>batsman_runs</th><th>extra_runs</th><th>total_runs</th><th>extras_type</th><th>is_wicket</th><th>player_dismissed</th><th>dismissal_kind</th><th>fielder</th><th>Runwides</th><th>RunsInOver</th></tr></thead><tbody><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>1</td><td>H Klaasen</td><td>AD Russell</td><td>AK Markram</td><td>1</td><td>0</td><td>1</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>2</td><td>AK Markram</td><td>AD Russell</td><td>H Klaasen</td><td>0</td><td>0</td><td>0</td><td>null</td><td>1</td><td>AK Markram</td><td>caught</td><td>MA Starc</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>3</td><td>Shahbaz Ahmed</td><td>AD Russell</td><td>H Klaasen</td><td>2</td><td>0</td><td>2</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>4</td><td>Shahbaz Ahmed</td><td>AD Russell</td><td>H Klaasen</td><td>0</td><td>0</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>5</td><td>Shahbaz Ahmed</td><td>AD Russell</td><td>H Klaasen</td><td>0</td><td>0</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>10</td><td>6</td><td>Shahbaz Ahmed</td><td>AD Russell</td><td>H Klaasen</td><td>6</td><td>0</td><td>6</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>9</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>1</td><td>Abdul Samad</td><td>AD Russell</td><td>H Klaasen</td><td>2</td><td>0</td><td>2</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>2</td><td>Abdul Samad</td><td>AD Russell</td><td>H Klaasen</td><td>1</td><td>0</td><td>1</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>3</td><td>H Klaasen</td><td>AD Russell</td><td>Abdul Samad</td><td>1</td><td>0</td><td>1</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>4</td><td>Abdul Samad</td><td>AD Russell</td><td>H Klaasen</td><td>0</td><td>1</td><td>1</td><td>wides</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>1</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>5</td><td>Abdul Samad</td><td>AD Russell</td><td>H Klaasen</td><td>0</td><td>0</td><td>0</td><td>null</td><td>1</td><td>Abdul Samad</td><td>caught</td><td>Rahmanullah Gurbaz</td><td>0</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>6</td><td>PJ Cummins</td><td>AD Russell</td><td>H Klaasen</td><td>4</td><td>0</td><td>4</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>0</td><td>10</td></tr><tr><td>1426312</td><td>1</td><td>Sunrisers Hyderabad</td><td>Kolkata Knight Riders</td><td>12</td><td>7</td><td>PJ Cummins</td><td>AD  ...

# %%
Bowling_1stInnings=FirstInnings.groupBy("bowler").agg(
    f.sum(f.col("batsman_runs")+f.col("Runwides")).alias("Runs"),
    f.sum("is_wicket").alias("Wicket"),
    f.count(f.when(f.col("Runwides")==0,1)).alias("Balls"),
    f.round(f.sum(f.col("batsman_runs")+f.col("Runwides"))*6/ f.count(f.when(f.col("Runwides")==0,1)),2).alias("Economy"),
    f.count(f.when(f.col("RunsInOver")==0,1)).cast(IntegerType()).alias("Maidens")
)
Bowling_1stInnings=Bowling_1stInnings.withColumn("Maidens",f.col("Maidens")/6)
Bowling_1stInnings=Bowling_1stInnings.withColumn("Maidens",f.col("Maidens").cast(IntegerType()))
Bowling_1stInnings=Bowling_1stInnings.withColumn("Overs",f.col("Balls")/6).withColumn("Overs",f.col("Overs").cast(IntegerType()))
Bowling_1stInnings=Bowling_1stInnings.withColumn("ExtraBalls",f.col("Balls")%6).withColumn("NewOvers",f.concat(f.lit(f.col("Overs")),f.lit("."),f.lit(f.col("ExtraBalls"))))
Bowling_1stInnings=Bowling_1stInnings.withColumn("Overs",f.col("NewOvers").cast(DoubleType())).select("bowler","Overs","Maidens","Runs","Wicket","Economy")
                                                                                                               
Bowling_1stInnings.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bowler</th><th>Overs</th><th>Maidens</th><th>Runs</th><th>Wicket</th><th>Economy</th></tr></thead><tbody><tr><td>Harshit Rana</td><td>4.0</td><td>1</td><td>24</td><td>2</td><td>6.0</td></tr><tr><td>SP Narine</td><td>4.0</td><td>0</td><td>16</td><td>1</td><td>4.0</td></tr><tr><td>MA Starc</td><td>3.0</td><td>0</td><td>14</td><td>2</td><td>4.67</td></tr><tr><td>AD Russell</td><td>2.3</td><td>0</td><td>19</td><td>3</td><td>7.6</td></tr><tr><td>VG Arora</td><td>3.0</td><td>0</td><td>24</td><td>1</td><td>8.0</td></tr><tr><td>CV Varun</td><td>2.0</td><td>0</td><td>9</td><td>1</td><td>4.5</td></tr></tbody></table></div>
